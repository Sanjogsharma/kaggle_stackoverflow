# %% [markdown]
# ##Give me some credit
#
# I am completing a (closed) kaggle competetion - show me the credit
# The competetion provided two data sets: a test set and and a training set
#
# 1) Importing packages for preliminary data analysis:

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sns
import mpld3

# %%
#import train and test data

train = pd.read_table('data/cs-training.csv', sep=',', header=False, index_col= 'Unnamed: 0')
#read file, changed index, changed names
 
test = pd.read_table('data/cs-test.csv', sep = ',', header=False,  index_col= 'Unnamed: 0')

# %%
train.head(3)
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                 1                              0.766127   45
# 2                 0                              0.957151   40
# 3                 0                              0.658180   38
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1                                     2   0.802982           9120
# 2                                     0   0.121876           2600
# 3                                     1   0.085113           3042
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                               13                        0
# 2                                4                        0
# 3                                2                        1
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 1                             6                                     0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
sns.set(style="white")
corr = train.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)


sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

# %%
train.groupby('SeriousDlqin2yrs').age.value_counts()
# Out:
# SeriousDlqin2yrs
# 0                 63     3583
#                   49     3524
#                   48     3520
#                   50     3474
#                   47     3413
#                   62     3405
#                   46     3390
#                   53     3384
#                   56     3382
#                   51     3354
#                   61     3347
#                   52     3332
#                   54     3317
#                   58     3279
#                   45     3218
#                   55     3196
#                   57     3192
#                   59     3113
#                   60     3108
#                   44     3052
#                   64     2964
#                   43     2932
#                   40     2829
#                   41     2828
#                   42     2793
#                   39     2707
#                   65     2502
#                   67     2424
#                   66     2414
#                   38     2396
# ...

# %%
train[train.SeriousDlqin2yrs == 0].age.describe()
# Out:
# count    139974.000000
# mean         52.751375
# std          14.791079
# min           0.000000
# 25%          42.000000
# 50%          52.000000
# 75%          63.000000
# max         109.000000
# Name: age, dtype: float64

# %%
train[train.SeriousDlqin2yrs == 0].age.describe()
# Out:
# count    139974.000000
# mean         52.751375
# std          14.791079
# min           0.000000
# 25%          42.000000
# 50%          52.000000
# 75%          63.000000
# max         109.000000
# Name: age, dtype: float64

# %%
abc, xyz = 1,2
